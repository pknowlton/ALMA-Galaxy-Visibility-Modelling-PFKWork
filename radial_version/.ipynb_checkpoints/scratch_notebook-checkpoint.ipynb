# %%
import numpy as np
from setup_mods import read_param_file, initialize_data
from galario.double import get_image_size
import ast

# %%
pwd
# Out:
# '/arc/home/pknowlton/git_repo/ALMA-Galaxy-Visibility-Modelling-PFK/radial_version'

# %%
def initialize_data(param_file):

    params={}
    with open(param_file, 'r') as f:
        for line in f:
            line = line.split("#", 1)[0].strip() #This will skip in-line comments
            if "=" in line:
                pkey, pvalue = line.split("=", maxsplit=1)
                pkey = pkey.strip()
                pvalue = ast.literal_eval(pvalue.strip())
                if isinstance(pvalue, list):
                    pvalue = np.array(pvalue, dtype=float)
                params[pkey] = pvalue

    u, v, re, im, w = np.require(np.loadtxt(params['visFile'], unpack=True), requirements='C')
    wavelength = 299792458/params['obsFreq']
    u /= wavelength
    v /= wavelength

    nx, dx = get_image_size(u, v)

    return params['radiusStart'], params['radiusStep'], params['radiusNumSteps'], nx, dx, u, v, re, im, w

# %%
args = initialize_data('/arc/home/pknowlton/git_repo/ALMA-Galaxy-Visibility-Modelling-PFK/radial_version/global_fitting_params.txt')

# %%
args
# Out:
# (0,
#  0.001,
#  25000,
#  4096,
#  1.8983707832917397e-07,
#  array([ 22350.41036289,  48724.0436182 , -23514.47206854, ...,
#           1508.16601931, -22055.15430278, -23563.3184608 ]),
#  array([ 5.67048418e+04,  2.59049300e+04,  5.05225438e+04, ...,
#          1.85920518e+05, -2.27975382e+01, -1.85943319e+05]),
#  array([-0.03102749,  0.01100424,  0.02566671, ..., -0.03183961,
#          0.02330604, -0.01934953]),
#  array([ 0.01602061, -0.03702213, -0.01300304, ..., -0.01824165,
#         -0.05576196, -0.02900367]),
#  array([ 913.0098,  941.8783,  947.345 , ..., 1114.625 , 1170.349 ,
#         1174.875 ]))

# %%
params
# Out:
# {'visFile': '/arc/projects/uvdisk_fit/ngc_3351/JS_data/cont93GHz/M95_C5+C2_cont93_uvtable.txt',
#  'obsFreq': 93000000000.0,
#  'numWalkers': 100,
#  'burnTime': 150,
#  'runTime': 3000,
#  'radiusStart': 0,
#  'radiusStep': 0.001,
#  'radiusNumSteps': 25000,
#  'dataFITSFile': '/arc/projects/uvdisk_fit/ngc_3351/JS_data/cont93GHz/M95_C5+C2_cont93_pbcorr_round.fits',
#  'plotCenterRA': '10h43m57.75s',
#  'plotCenterDec': '11:42:13.34deg',
#  'plotBoxSide': 40,
#  'plotName': 'Perturbed Initial Guess',
#  'uvbinSize': 0}

# %%
data = initialize_data(params['visFile'], params['obsFreq'])

# %%
data[0]
# Out:
# 4096

# %%
def log_print(prin_pars):
    print(prin_pars)

# %%
def log_prior(pars):

    peak, sigma, ring_rad, inclination, posangle, dRA, dDec = pars

    print(peak, ring_rad)
    log_print(pars)

    for i in (pars):
        print(i)

# %%
pars = [8, 2, 4, 9, 1, 2, 9]

# %%
log_prior(pars)
# Out:
# 8 4
# [8, 2, 4, 9, 1, 2, 9]
# 8
# 2
# 4
# 9
# 1
# 2
# 9

# %%
model_fits_ranges = [[-5, 15], [0, 10], [0, 20], [0, 90], [0, 180],[-5, 5], [-5, 5]]

# %%
model_fit_ranges

# %%
pwd
# Out:
# '/arc/home/pknowlton/git_repo/ALMA-Galaxy-Visibility-Modelling-PFK/radial_version'

# %%
def log_prior(pars):

    model_fits_ranges = [[-5, 15], [0, 10], [0, 20], [0, 90], [0, 180],[-5, 5], [-5, 5]]

    for i in range(len(pars)):
        if not model_fits_ranges[i][0] < pars[i] < model_fits_ranges[i][1]:
            return -np.inf
    return 0.0

# %%
pars = [8, 2, 4, 9, 1, 2, 4]

# %%
log_prior(pars)
# Out:
# 0.0

# %%
def log_prob(pars):
    lp = log_prior(pars)
    if not np.isfinite(lp):
        return -np.inf
    else:
        return 0.0

# %%
log_prob(pars)
# Out:
# 0.0

# %%
model_fits_ranges = [[-5, 15], [0, 10], [0, 20], [0, 90], [0, 180],[-5, 5], [-5, 5]]
model_fits_initial_guesses = [6, 1, 7, 60, 15, 0, 0]

# %%
nwalkers = 32
ndim = len(model_fits_ranges)
pos = np.zeros([nwalkers, ndim])

# %%
for i in range(nwalkers):
    c = 0
    while c != 1:
        pos[i, :] = model_fits_initial_guesses + 1e-5*np.random.randn(ndim)
        chk_pars = log_prior(pos[i,:])
        if chk_pars == 0:
            c = 1
print('All guesses within prior range')
# Out:
# All guesses within prior range

# %%
pos
# Out:
# array([[ 6.00001802e+00,  9.99999370e-01,  6.99999808e+00,
#          6.00000054e+01,  1.49999915e+01,  8.41291060e-06,
#         -1.18977208e-05],
#        [ 6.00001955e+00,  1.00000930e+00,  6.99998976e+00,
#          5.99999934e+01,  1.50000093e+01,  1.12688035e-05,
#         -1.25377597e-05],
#        [ 6.00000330e+00,  9.99985231e-01,  6.99999673e+00,
#          5.99999974e+01,  1.50000001e+01,  4.51842150e-06,
#         -4.23089650e-06],
#        [ 5.99997769e+00,  1.00000420e+00,  6.99998557e+00,
#          5.99999912e+01,  1.50000124e+01,  1.09830121e-05,
#         -7.51695600e-06],
#        [ 6.00002747e+00,  9.99993247e-01,  7.00001886e+00,
#          5.99999997e+01,  1.50000080e+01, -1.62110706e-05,
#          6.81754686e-06],
#        [ 6.00000393e+00,  9.99998201e-01,  6.99998209e+00,
#          6.00000114e+01,  1.49999845e+01, -3.92416151e-06,
#         -2.27323188e-06],
#        [ 6.00000487e+00,  9.99997414e-01,  7.00002304e+00,
#          5.99999948e+01,  1.50000081e+01, -4.70909917e-06,
#         -2.52914927e-06],
#        [ 5.99999211e+00,  1.00001899e+00,  6.99999915e+00,
#          5.99999902e+01,  1.50000027e+01, -1.42053050e-05,
#          1.07125265e-06],
#        [ 5.99999387e+00,  1.00000186e+00,  7.00001486e+00,
#          5.99999896e+01,  1.49999966e+01, -2.79188166e-06,
#         -1.03041715e-06],
#        [ 6.00000355e+00,  9.99992245e-01,  7.00001784e+00,
#          5.99999951e+01,  1.50000091e+01,  2.04210692e-05,
#         -1.35901608e-05],
#        [ 5.99999706e+00,  1.00000115e+00,  6.99999323e+00,
#          5.99999819e+01,  1.50000019e+01, -1.01015948e-05,
#         -4.91633239e-06],
#        [ 6.00000035e+00,  1.00000100e+00,  7.00002075e+00,
#          6.00000039e+01,  1.50000098e+01, -1.46322774e-05,
#          2.66949214e-06],
#        [ 6.00000019e+00,  9.99993533e-01,  6.99999827e+00,
#          5.99999981e+01,  1.49999971e+01, -1.50690810e-05,
#         -4.23679744e-07],
#        [ 5.99998255e+00,  1.00001805e+00,  6.99999326e+00,
#          5.99999940e+01,  1.50000309e+01, -3.71758587e-08,
#         -6.04319068e-07],
#        [ 5.99998877e+00,  1.00000689e+00,  7.00001972e+00,
#          5.99999980e+01,  1.49999936e+01,  6.37128116e-06,
#         -1.48866843e-06],
#        [ 5.99999936e+00,  9.99997869e-01,  7.00000130e+00,
#          6.00000089e+01,  1.50000164e+01,  1.17377213e-06,
#          8.54305969e-06],
#        [ 5.99999645e+00,  1.00000587e+00,  7.00001266e+00,
#          5.99999991e+01,  1.50000099e+01, -1.52673086e-05,
#         -7.68437523e-07],
#        [ 5.99999803e+00,  9.99977440e-01,  7.00000189e+00,
#          5.99999937e+01,  1.49999954e+01,  2.54172599e-06,
#         -9.79186649e-06],
#        [ 6.00000648e+00,  9.99977804e-01,  7.00000764e+00,
#          5.99999897e+01,  1.49999743e+01,  1.46594245e-05,
#         -5.80790507e-06],
#        [ 6.00002330e+00,  9.99993316e-01,  6.99999286e+00,
#          6.00000058e+01,  1.49999885e+01, -1.74051096e-05,
#          1.15737026e-05],
#        [ 5.99999335e+00,  9.99976744e-01,  6.99999451e+00,
#          5.99999947e+01,  1.49999881e+01,  1.10056584e-05,
#          7.18855356e-06],
#        [ 6.00000428e+00,  9.99997508e-01,  7.00000403e+00,
#          5.99999985e+01,  1.49999898e+01, -1.36704560e-05,
#          5.61486062e-06],
#        [ 5.99998919e+00,  1.00001669e+00,  6.99998851e+00,
#          6.00000047e+01,  1.49999970e+01,  2.24989311e-05,
#          2.62721773e-07],
#        [ 6.00000491e+00,  1.00001514e+00,  6.99997971e+00,
#          6.00000070e+01,  1.49999944e+01, -1.34242330e-05,
#          9.12429201e-06],
#        [ 6.00002324e+00,  1.00000826e+00,  7.00000571e+00,
#          6.00000028e+01,  1.50000018e+01, -9.10995661e-06,
#          3.45658798e-06],
#        [ 5.99999713e+00,  9.99988856e-01,  7.00000084e+00,
#          6.00000008e+01,  1.49999923e+01,  3.45596116e-06,
#         -2.92546593e-06],
#        [ 5.99999053e+00,  1.00001383e+00,  6.99999729e+00,
#          5.99999972e+01,  1.49999919e+01, -1.18263245e-05,
#          2.09094366e-06],
#        [ 5.99999448e+00,  1.00000524e+00,  7.00000278e+00,
#          6.00000135e+01,  1.49999933e+01,  4.90420611e-07,
#         -5.64500660e-06],
#        [ 5.99998792e+00,  9.99997696e-01,  7.00000813e+00,
#          6.00000051e+01,  1.49999884e+01,  1.27751951e-06,
#         -4.30535872e-06],
#        [ 6.00000708e+00,  1.00000115e+00,  7.00001661e+00,
#          5.99999752e+01,  1.49999891e+01, -5.12105954e-07,
#         -6.10365004e-06],
#        [ 6.00000988e+00,  9.99988096e-01,  6.99999235e+00,
#          6.00000115e+01,  1.50000095e+01, -1.20456349e-05,
#         -2.05624630e-06],
#        [ 5.99999158e+00,  9.99994324e-01,  6.99998947e+00,
#          6.00000032e+01,  1.49999994e+01,  1.37471927e-05,
#          7.04109712e-06]])
